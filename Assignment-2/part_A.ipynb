# %%
# Name : Harshvardhan Rokade
# Roll No : 117
# Batch : B2


import pandas as pd

s = pd.Series([10 , 20 , 30 , 40 , 50] , index = ['a' , 'b' , 'c' , 'd' , 'e'])         #Creating series
print(s)                                                                                #Printing the series

print(s['a'])                                                                           #Acessing single values
type(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# 10
# pandas.core.series.Series

# %%
data = {
    'Name' : ['Harsh' , 'Sumit' , 'Vivek'],                             #Creating dataframe
    'Age' : [20 , 21 , 22],
    'Marks' : [90 , 95 , 80]
}

df = pd.DataFrame(data)
print(df)                                                                #Printing dataframe

print("Single values")                                                             
print(df['Name'])                                                        #Acessing single values

type(df)
# Out:
#     Name  Age  Marks
# 0  Harsh   20     90
# 1  Sumit   21     95
# 2  Vivek   22     80
# Single values
# 0    Harsh
# 1    Sumit
# 2    Vivek
# Name: Name, dtype: object
# pandas.core.frame.DataFrame

# %%
s = pd.Series([100 , 200 , 300 , 400 , 500])                            #Arithmetic Operations
print(s)
print(s*5)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64
# 0     500
# 1    1000
# 2    1500
# 3    2000
# 4    2500
# dtype: int64

# %%
df['Name']                                              #Single row
df[['Name' , 'Marks']]                                  #Multiple row
df.iloc[1]                                              #Row by index
df.iloc[0:2]                                            #Index by range
df.loc[df['Age'] > 50]                                  #Filter condition
# Out:
# Empty DataFrame
# Columns: [Name, Age, Marks]
# Index: []

# %%
import pandas as pd

df = pd.read_csv("netflix_titles.csv", encoding="latin1" , usecols=lambda col: not col.startswith('Unnamed'))

# %%
df.head()        # first 5 rows
df.tail()
df.shape         # (rows, columns)
df.info()        # summary (data types, non-null count)
df.dtypes        # data types of each column
df.describe()    # summary statistics (mean, std, min, max, etc.)
df.columns       # list of column names
df.index         # row index
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8809 entries, 0 to 8808
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8809 non-null   object
#  1   type          8809 non-null   object
#  2   title         8809 non-null   object
#  3   director      6175 non-null   object
#  4   cast          7984 non-null   object
#  5   country       7978 non-null   object
#  6   date_added    8799 non-null   object
#  7   release_year  8809 non-null   int64
#  8   rating        8805 non-null   object
#  9   duration      8806 non-null   object
#  10  listed_in     8809 non-null   object
#  11  description   8809 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 826.0+ KB
# RangeIndex(start=0, stop=8809, step=1)

# %%
df.describe()                                   # summary statistics (mean, std, min, max, etc.)
df['release_year'].mean()                       # average release year
df['release_year'].median()                     # median year
df['release_year'].max()                        # latest year
df['release_year'].min()                        # earliest year
df['release_year'].value_counts().head(10)      # top 10 frequent years
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     353
# 2013     288
# 2012     237
# Name: count, dtype: int64
