# %%
import pandas as pd

df = pd.read_csv("student_dataset.csv")

# %%
df.head()        # first 5 rows
df.tail()
df.shape         # (rows, columns)
df.dtypes        # data types of each column
df.describe()    # summary statistics (mean, std, min, max, etc.)
df.columns       # list of column names
df.index         # row index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.describe()                                   # summary statistics (mean, std, min, max, etc.)
df['Marks'].mean()                              # average release year
df['Marks'].median()                            # median year
df['Marks'].max()                               # latest year
df['Marks'].min()                               # earliest year
df['Marks'].value_counts().head(10)             # top 10 frequent years
# Out:
# Marks
# 65    28
# 90    27
# 86    26
# 76    23
# 79    23
# 56    21
# 98    21
# 68    21
# 64    20
# 88    20
# Name: count, dtype: int64
